# %% [markdown]
# <a href="https://colab.research.google.com/github/McDarius24/CSC121-spring2026-assignments/blob/main/Week5/Week_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
def calculate_ticket(age, hour):
    # 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
    if age <= 12 or age >= 65:
        price = 8
    else:
        price = 12

    # 3. Logic: If hour < 17, subtract 2 from the price.
    if hour < 17:
        price -= 2
    # 4. Print the final price.
    print(f"The ticket price is: ${price}")

# PROGRAM LOGIC
# 1. input() for age (int)
# 2. input() for movie hour (int)
# 3. Call calculate_ticket()

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
def calculate_ticket(age, hour):
    # 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
    if age <= 12 or age >= 65:
        price = 8
    else:
        price = 12

    # 3. Logic: If hour < 17, subtract 2 from the price.
    if hour < 17:
        price -= 2
    # 4. Print the final price.
    print(f"The ticket price is: ${price}")

# PROGRAM LOGIC
# 1. input() for age (int)
age = int(input("Enter your age: "))
# 2. input() for movie hour (int)
hour = int(input("Enter the movie hour (24-hour format): "))
# 3. Call calculate_ticket()
calculate_ticket(age, hour)
# Out:
# Enter your age: 70
# Enter the movie hour (24-hour format): 17
# The ticket price is: $8
