# %% [markdown]
# <a href="https://colab.research.google.com/github/McDarius24/CSC121-spring2026-assignments/blob/main/Week4/Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Statements

#Function Definitions
# Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
# Inside the function, use string multiplication (*) for a border line.
 border_line= "*" *20
# Print the bio details using the parameter names.
 print(border_line)
 print(f"Name: {name}")
 print(f"Age: {age}")
 print(f"Goal: {goal}")
 print(border_line)


#Program Logic
# 1. Call print_bio using my own info.
print_bio(name="McDarius", age=25, goal="Learn Python")
# 2. Call print_bio using [Name of Famous Person].
print_bio(name="Kevin Hart", age=46, goal="make jokes")
# 3. Call print_bio using [Name of Fictional Character].
print_bio(name="superman", age="unknown", goal=" Save lives")
# Out:
# ********************
# Name: McDarius
# Age: 25
# Goal: Learn Python
# ********************
# ********************
# Name: Kevin Hart
# Age: 46
# Goal: make jokes
# ********************
# ********************
# Name: superman
# Age: unknown
# Goal:  Save lives
# ********************
