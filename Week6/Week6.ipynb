# %% [markdown]
# <a href="https://colab.research.google.com/github/McDarius24/CSC121-spring2026-assignments/blob/main/Week6/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# 1. Import math
import math

# FUNCTION DEFINITIONS
# 1. Define area(radius): returns pi * r squared
def  area(radius):
    return math.pi * radius ** 2
# 2. Define circumference(radius): returns 2 * pi * r
def circumference(radius):
    return 2 * math.pi * radius
# 3. Define volume(radius, height):
def volume(radius, height):
    #    - Call area(radius) and multiply by height.
    return area(radius) * height
#    - Return the result.


# PROGRAM LOGIC
# 1. Input for radius (float)
radius_input = float(input("Enter a radius: "))
# 2. Call and print area and circumference.
print(f"Area: {area(radius_input):.2f}")
# 3. Input for height (float)
height_input = float(input("Enter a height: "))
# 4. Call and print volume.
print(f"Volume: {volume(radius_input, height_input):.2f}")
# Out:
# Enter a radius: 5
# Area: 78.54
# Enter a height: 10
# Volume: 785.40
